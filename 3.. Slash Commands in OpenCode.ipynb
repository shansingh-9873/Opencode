# %%
'''

Section : Slash commands in [OpenCode logo]


1.. What are Slash Commands ?
2.. Built-in Slash Commands !
3.. Custom Slash commands !
4.. [DEMO] : Define Custom Slash commands !


'''

# %% [markdown]
# # 1.. What are Slash Commands ?

# %%
'''


Its a very imp topic & bcz of this actually , OpenCode is very popular !

Slash Commands : These are shortcuts that you type inside a Claude Code session to triggersome pre-defined action..
                 Slash commands starts using "/"
                 
                 
                 See usually , what happends is that :
                 User/Programmers talks to AI via prompt to do some tasks :
                     like Debug this testing code
                          read this JSON file
                          read this csv file
                          clean this excel data
                          clean this csv data
                        
                 [diagram]
                 
                 So AI developers have figured out that :
                 Programmers usually use same things while coding , so
                 
                 OpenCode Deevloper ->> thinks lets convert -> these re-usuable patterns/workflows /same thing
                                                             that programmer use ->> commands 
                                                             
                 In simple words :
                     Something that is repeatitive -> Convert it into Commands ( thats called Slash Commands)
                                                             
                                                             
                Its main adv is :
                    You do not have to write prompt again & again to explain something to AI..
                    You just write 1 word ( this one word will invoke/call the entire prompt)
                    
                    
                    
                    
                Now lets have quick hands on where I will show u some slash commands !
                Open VSCODE 
                
                
                if u press / here , u can check all the slash commmands here !
                /models ->> helps u to switch model 
                /connect ->>  it will give u various Models to which u can connect your OpenCode Agent !
                /exit → it will close OpenCode Agent
                
                    
                    
                    
                And in the next session…
                We’ll go even deeper into in-built slash commands & custom commands !

'''

# %% [markdown]
# # 2.. Built-in Commands

# %%
'''

Hi there , In the last session…
we understood what slash commands are. , Now let’s go one level deeper 🚀

Let’s talk about:
👉 Types of Slash Commands

    In general… there are only 2 types:
        👉 Built-in commands
        👉 Custom commands


"When you install OpenCode..
You already get:

    👉 Built-in slash commands

     So now , lets first show u built-in slash commands  !

    
    & when I type slash "/" , u can see list of all the in-built slash commands !
    

    
👉 /models → it will give us option to Switch models for our OpenCode Agent ( like we can opt for FRee models like Deepseek ,
                Paid models like GPT , Opus etc )
👉 /exit → it will close OpenCode Agent
👉 /sessions → helps u switch session/conversation if u have mutliple sessions in your Project !







    Imagine You are a Manager & you want summary of this project in every morning to get a update of what is going in my Project !
    , so question is : Can I run  /summary or /explain type of commands here ?
    
    Ans : No , bcz /explain is not defined by OpenCode developers , 
          If u want summary of your Project , u have to manually define custom commands for that & thats what we 
          we will learn in next session !



'''

# %% [markdown]
# ## 3.. Custom Slash Commands !

# %%
'''

Hi there 👋

Now let’s learn something really powerful…
👉 How to create your own custom command in OpenCode.

Custom Slash Commands are those commands : which u can build for your workflows/or for your Projects as per need !


Lets continue with the same Sales analysis Project on which we were working on : 
Show [hierarchy]





'''

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
'''

In order to create custom commans,  u have to 3 step procedure :
    lets understand !


✅ Step 1

    First, go inside our project folder…
    and create a new folder called : 👉 .opencode

    Think of this as your toolbox 🧰
    where all OpenCode-related settings will live..


✅ Step 2

    Now, inside this .openCode folder…
    create another folder called : 👉 commands

    You can think of this as a collection of tools…
    or simply, all your custom commands.



✅ Step 3
    Inside commands folder, create: 👉 explain.md
    This file will define what your command actually does.



    Inside explain.md  , put :
    Explain the sales_analysis.py code in a clear and simple way.

    - Break it step by step
    - Use beginner-friendly language
    - Explain purpose of each block
    - Avoid jargon

    If it's a full file, summarize it..




    So in simple words 

    .openCode → your toolbox/lab
    commands → tools inside it
    .md file → actual custom command logic


    “and OpenCode automaticallye scans the folder .openCode/commands/ to find out Custom commands defined by you”

    You don’t need to:

    install anything ❌
    restart manually (in most cases) ❌



If you simply type:

    👉 /explain

    OpenCode will automatically understand… and explain your entire project
    based on the instructions you defined.


So if your manager asks:
👉 “Explain your project…”

You won’t panic 😄

You’ll just run:

👉 /explain

    That’s the power of custom commands in OpenCode 🚀

'''

# %% [markdown]
# # 3.. Sessions !

# %%
'''

Hi there , since we understood what commands are & when to use slash commands  !

now lets understand one of the most IMPORTANT concepts in OpenCode which is : Sessions 

    So what is a session?
    👉 A session = One conversation with OpenCode
        Like here in this Project , 
        [show vscode] , this entire Conversation that u have done to OpenCode is 1 session
        
        When I click again on this OpenCode Icon / when u launch your Agent again , a new session have been created !



    So when u create a new terminal for OpenCode , 👉 Session starts..
    & then you do all the conversation with OpenCode & When you exit that terminal using /exit , 👉 Session ends..
    
        So this entire in between conversation is actually one session !
        
        So everything in between…

        👉 your prompts
        👉 your code
        👉 your questions

All of that = one session
        

But here’s the magic…

👉 OpenCode saves EVERYTHING.

    Your prompts
    Your code
    Your conversation with AI
    
    Usually these sessions are stored at some config files in Claude , if u want to store these
    sessions into project directory :
    use / export [file_name]
    use /export file.md
    
    Importance of this file :
    You can provide this file as a context to OpenCode & then u can plan changes in your code..
    

See every session has:

    👉 A unique ID
    👉 Full history








    Now You may ask : why sessions are important?

    Because of something called… 👉 OpenCode
    (which you studied this in the next module 👀)

See , its a good practice to create 1 session each for building 1 feature in your Project !

👉 otherwise OpenCode gets confused
👉 and Context gets messy


Lets Understand it with a Real world Scanario : 


[Show Udemy Course Content img]
Imagine u are building a Learning Platform or a Scalable product like Udemy :
    so u can create one session each in Claude for every feature of Udemy : 
    like :
    
    One session for this feature : Learning Tools
    One session for this feature : Notes
    One seesion for Announcements feature 
    
    
    So always create 1 session each for 1 feature , once it is build , close that session !
    
    
    
    This keeps everything clean..

    This is how real AI engineers work.


'''

# %% [markdown]
# ## 4.. Best Practices

# %%
'''

"Now let’s talk about some of the best practises that u can use
    in day - 2 -day life which separates beginner From professionals..

    Because tools don’t make you powerful…
        👉 How you use them actually does.


Here are some of the best practices which I have gathered while working on Projects :

👉 1. One Session = One Task
        As this Keeps separation of task & your context windows doesn't mix up !

👉 2. Name your sessions
        Give sessions name immediately once u craete it , so that u can easily 
        differentiate between multiple sessions..
        [ Go to VScode & u can change name of session for better clarity ]
        In CLI : /rename intro_session
        

👉 3. Always Use built-in commands first
        Don’t reinvent everything




'''
