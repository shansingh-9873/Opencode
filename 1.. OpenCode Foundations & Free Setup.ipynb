# %% [markdown]
# # 1.. Welcome & What You’ll Build :

# %%
'''

Hi there , in this course , we will learn OpenCode from complete beginner…
    to someone who can actually use OpenCode like a pro..
    & then we will build Agents & Automate our workflows using Claude Code !
    


    First, we’ll build a strong foundation.

    You’ll understand:

        How OpenCode is different from Other Agents like Claude , Codex 
        How OpenCode actually works behind the scenes
        
    Then we’ll go deeper…
    Where You’ll learn powerful concepts of Claude like:

        How to manage the context window
        plan and build mode
        Slash commands
        How to create agents and sub-agents
        How to use the AGENTS.md file
        
   And also…

        AGENTS.md
        Skills, 
        Custom Agents
        MCP, 
        rules
        Hooks
        Plugins

All the core concepts…
then we will :

    👉 Build Real-World AI agents using OpenCode 10X faster 
    👉 Automate coding tasks
    👉 Work on real-world use cases

    


'''

# %% [markdown]
# # 2.. What OpenCode is -

# %%
show Image already : OpenCode = LLM + Tools

# %%
'''
Hi there , now lets understand what exactly is OpenCode?
    In layman terms : It’s an agent built on top of an LLM
    
Think of it like this 👇
At the core, there is an LLM — a large language model.

You can think of it as:
🧠 The brain




Now, here’s the important part…
    A brain alone can think…
    but it cannot actually do anything in the real world.
    Right?

It can’t open files
It can’t write code in your system
It can’t run commands
It can search Internet & fetch Info from there !


So the question is…

👉 How do we make this brain actually useful?

    That’s where Tools come in.
    When we connect this brain to tools…
    Now everything changes..
    
    because using Tools , now it can:

✅ Read files from your computer using Read Tool
✅ It can Write code for your Project using Write Tool
✅ It can Run commands using Terminal / Bash Tool
✅ It can search the entire Internet using Web Search Tool







    [ open VS CODE]
    Let me quick demo about Open Code , Forget about the setup , I will explain u in upcoming lesson !
    
	Now if u say :
	"Create a Python function to add 3 numbers !
	OpenCode Agent is able to create file & store code into that !
    
    
    
[show CHATGPT/CLAUDE]
    Now u may say : Whats a Big Deal !
    If u ask Claude AI or chatgPT or Gemini same thing , they are able to return code  , 
    but they are not able to create files or edit files for you  ,managing repos !
    
    
[show VS CODE]
	If u are wondering , Why it is happening so  ?
	Bcz of Tool-call !
	LLM returns code & Write Tool create this Python file !



	Do a Google Search as :
	OpenCode built-in Tools(Tools provided by OpenCode) ->> go to overview

	Read , 
	Write
	Edit
	Bash
	Glob
	Grep
	WebSearch
	WebFetch




So if I simplify everything into one line:

👉 Claude Code = Brain (LLM) + Tools (Action Layer)


    So coming to LLM/Brain , you can use any LLM that you want :
        Your free models or
        Your Paid Models ( CLAUDE , GPT Models , GEmini ) 
        even models that contains like API keys or 
        local models








'''

# %% [markdown]
# # 3.. How OpenCode works Internally ?

# %%
'''

See we know : 
OpenCode = LLM + Built-in tools 


Although u can add custom tools using MCP , which we will learn in near future , but just for sake of simplicity
lets understand how does OpenCode works internally  , the moment u give some task or any Prompt !






Query ->> Read this Database file !
User Query
    ↓
"Read this database file"
    ↓
LLM
    ↓
Generates Python code
    ↓
At this stage:
Pure Generative AI
(Because the model is only predicting text/code)


It is only generating text such as:
import sqlite3
import pandas as pd

conn = sqlite3.connect("sales.db")
df = pd.read_sql("SELECT * FROM Users", conn)    
    
    
    
    
    
It means , LLMs are doing their work , but they cannot read files, create files, 
        run code, or access your computer.

but when Tools comes , Agentic Nature comes !


Tools[ Receives code as I/P ] ->> create new file ( using Write Tool) in our codebase 
        How Write tools create new file in our codebase ?
            A Write Tool might internally use some command like : 
                with open("explore_db.py", "w") as f:
                    f.write(code)







User Query
    ↓
"Read this database file"
    ↓
LLM
    ↓
Generates Python code
    ↓
At this stage: Pure Generative AI
(LLM is only generating text/code)
But LLM cannot read files, create files, run code, or access your computer.
    ↓
Generated code is passed to a Write Tool
    ↓
Write Tool Creates a new Python file in the codebase
    ↓
Tool internally uses File System APIs
(e.g., open(), write(), Path.write_text())
    ↓
New file successfully created
    ↓
Agent observes the result
    ↓
Task completed



'''

# %% [markdown]
# # 4.. Agentic Coding vs Traditional Coding !

# %%
'''

Hi there , 
"now lets understand what is simple diff between Traditional Coding vs Agentic Coding that we often do using Claude Code !



Let’s break it"Agentic Coding" down :

    👉 Agent = AI that can perform tasks
    👉 Agentic = Multiple agents like agent1 , agent2 , agent3 & they are  working together

That’s it..

    Coding : set of instructions/Code which u give to system or to Agent to perform certain tasks !



    [ show Udemy without sign-In]
Now imagine this…
👉 You want to build a website/Platform like Udemy.
    A full platform where:

    Users can sign up
    Instructors can upload courses
    Students can watch videos, they can review courses , evrything !
    
    normally… , This is a HUGE complex project !

    You would need:

        Frontend developer
        Backend developer
        Database engineer
        DevOps

        And it could take Months to build a such a Scalable Product like Udemy !

    But now…

    Let’s do the same thing using Agentic Coding.
    Instead of doing everything yourself…

    👉 You create a TEAM of AI agents.
            OR
    You assign tasks by creating multiple agents : 

    👨‍💻 Agent 1 → Build UI
    👨‍💻 Agent 2 → Handle backend
    👨‍💻 Agent 3 → Database Agent
    
    
    & then u have to validate the work done by your Agents !




& This is amazing !

Because:

👉 Your Work becomes faster
👉 System becomes scalable


Now think like a manager…
You don’t have to code everything…

👉 You just assign work & Agents will do it & u have to validate the work !


That is : 👉 Agentic Coding


'''

# %% [markdown]
# # 5.. OpenCode Free setup

# %%
'''

Opencode in Terminal
Desktop Version




Install opencode
    Do a simple search as : install claude command terminal
            You’ll find an installation command.
            Now here’s important:

            If you’re on Mac → copy Mac command
            If you’re on Windows → copy Windows command
        
            & if U are Windows User , U have to open Command Prompt/Powershell & paste the command & hit enter !
                
            Command : npm i -g opencode-ai

              if U are Mac User , U have to open terminal & paste the command & hit enter !
    
    
        After installation… you’ll see something like:
            ✅ opencode successfully installed
        



    
Run opencode
        Run opencode by this command : opencode
        If u want to run opencode in your project directory , firts navigate to the Project using cd command !
        
        cd 
        Then launch 


        

Choose Model/LLM for OpenCode !
        So, if you want to connect to do any model, simply type /connect. 
        And here you can see we have the options here to connect to any large language model provide
        
        
        There are two main types of AI model providers:
        1. Subscription-based
            Pay a fixed monthly fee (e.g., $5, $10, $20).
            
        2. Pay-as-you-go
            Use your own API key.
            
            
            
        



'''

# %% [markdown]
# # 6.. OpenCode Paid setup !

# %%
'''
use /connect again !


OpenCode Go is the subscription-based option.
It costs around $5/month.
The subscription provides access to multiple top-tier models, including models from Chinese providers.
These models can be used directly inside OpenCode.
Another option is using an existing ChatGPT Plus or Pro subscription.
If you already have a ChatGPT subscription, you can authenticate here as well !!



'''

# %% [markdown]
# # 7.. First command + Plan vs Build mod

# %%
'''



Run query :  
            Now the fun part…
            Let’s run your first command. : 
            
            "So First, we need to move into our project folder." !
            So Current working directory is C drive & we have our Porject in R drive !
            
            So create new terminal , change drive & directory both !
            for that , u have to use cd command , which means : change directory 
            /d allows switching drive + directory together
            
            cd /d ["R:\Claude\Files\Sales"] : which is this one  , copy & put it
                Make sure it has forward slashes 
                Hit Enter 
                


            and Now let’s ask a simple question :
            What the Project is all about ?
            

            OpenCode will reads the entire code-base & explain this Project !
            saying : Hey , this is a Amazon Sales data analysis project where
           YOu have done all these things like : collect data , clean data & other stuffs !
           
           & even it is recommeding bug in the code !
           & thats a power of OpenCode !






'''
